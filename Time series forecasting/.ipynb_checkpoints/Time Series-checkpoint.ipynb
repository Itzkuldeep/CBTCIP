# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Obtaining dependency information for statsmodels from https://files.pythonhosted.org/packages/d5/7e/61ec96b208af273126a211a9aa1c9dfefb216725192973fc52a858ac9219/statsmodels-0.14.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading statsmodels-0.14.2-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\kulde\anaconda3\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\kulde\anaconda3\lib\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\kulde\anaconda3\lib\site-packages (from statsmodels) (2.2.0)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Obtaining dependency information for patsy>=0.5.6 from https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl.metadata
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\kulde\anaconda3\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kulde\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kulde\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kulde\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in c:\users\kulde\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.9 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/9.9 MB 6.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/9.9 MB 8.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/9.9 MB 9.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.2/9.9 MB 10.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.7/9.9 MB 10.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.9 MB 10.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/9.9 MB 10.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.4/9.9 MB 10.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.9 MB 11.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.1/9.9 MB 11.1 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.2/9.9 MB 11.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.8/9.9 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/9.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 11.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 10.9 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ---------------------------------------- 233.9/233.9 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2

# %%
import pandas as pd
import yfinance as yf
import datetime
from statsmodels.tsa.arima_model import ARIMA
from datetime import date, timedelta
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
today = date.today()

# %%
d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=365)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

# %%
data = yf.download('GOOG', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.tail())
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 245 2024-06-04  174.449997  175.190002  173.220001  175.130005  174.930939
# 246 2024-06-05  176.535004  177.970001  175.289993  177.070007  176.868744
# 247 2024-06-06  177.429993  178.710007  177.210007  178.350006  178.147278
# 248 2024-06-07  178.460007  179.419998  175.789993  175.949997  175.750000
# 249 2024-06-10  176.449997  178.470001  174.380005  176.630005  176.630005
#
#        Volume
# 245  14066600
# 246  15233900
# 247  14255800
# 248  14716300
# 249  17122200

# %%
data = data[["Date", "Close"]]
print(data.head())
# Out:
#         Date       Close
# 0 2023-06-13  124.430000
# 1 2023-06-14  124.379997
# 2 2023-06-15  125.790001
# 3 2023-06-16  124.059998
# 4 2023-06-20  123.849998

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))
plt.plot(data["Date"], data["Close"])

# %%
result = seasonal_decompose(data["Close"], model='multiplicative', freq = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(15, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 result = seasonal_decompose(data["Close"],
#       2                             model='multiplicative', freq = 30)
#       3 fig = plt.figure()
#       4 fig = result.plot()
#
# TypeError: seasonal_decompose() got an unexpected keyword argument 'freq'

# %%
pd.plotting.autocorrelation_plot(data["Close"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data["Close"], lags = 100)

# %%
p, d, q = 5, 1, 2
model = ARIMA(data["Close"], order=(p,d,q))  
fitted = model.fit(disp=-1)  
print(fitted.summary())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[26], line 2
#       1 p, d, q = 5, 1, 2
# ----> 2 model = ARIMA(data["Close"], order=(p,d,q))
#       3 fitted = model.fit(disp=-1)
#       4 print(fitted.summary())
#
# File ~\anaconda3\Lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
predictions = fitted.predict()
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 predictions = fitted.predict()
#       2 print(predictions)
#
# NameError: name 'fitted' is not defined

# %%
import statsmodels.api as sm
import warnings
model=sm.tsa.statespace.SARIMAX(data['Close'],
                                order=(p, d, q),
                                seasonal_order=(p, d, q, 12))
model=model.fit()
print(model.summary())
# Out:
# C:\Users\kulde\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'

# %%
predictions = model.predict(len(data), len(data)+10)
print(predictions)

# %%
data["Close"].plot(legend=True, label="Training Data", figsize=(15, 10))
predictions.plot(legend=True, label="Predictions")
